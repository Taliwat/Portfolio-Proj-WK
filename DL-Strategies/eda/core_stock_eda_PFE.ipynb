# %% [markdown]
# # **Core Stock Data EDA for PFE Ticker**
# ## In this notebook we will examine only the Pfizer stock for the periods we have selected for this project (03-14-2019 through 08-15-2024), and see what we can derive from it through our plots.  We will look at each of our core stock tickers separately in order to gain a better analysis.

# %% [markdown]
# #### Let's start by bringing in the libraries and logic necessary for reading in our file.

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import linregress
from scipy.stats import gaussian_kde
import mplfinance as mpf

# %% [markdown]
# #### Now let's read in our data that we need for this notebook.

# %%
# Now let's access the main core_stock_data.csv file
csv_path = os.path.join(project_root, 'data', 'core_stock_data.csv')
core_stock_data = pd.read_csv(csv_path, parse_dates=['Date'], index_col= 'Date')
core_stock_data.head()
# Out:
#             Close_core  Volume_core  Open_core  High_core   Low_core  \
# Date
# 2019-03-14   45.932499     94318000  45.974998  46.025002  45.639999
# 2019-03-15   46.529999    156171600  46.212502  46.832500  45.935001
# 2019-03-18   47.005001    104879200  46.450001  47.097500  46.447498
# 2019-03-19   46.632500    126585600  47.087502  47.247501  46.480000
# 2019-03-20   47.040001    124140800  46.557499  47.372501  46.182499
#
#             SMA_core   EMA_core   RSI_core  BBM_core   BBU_core  ...  \
# Date                                                             ...
# 2019-03-14  41.35925  42.219051  75.741602  41.35925  46.695085  ...
# 2019-03-15  41.50025  42.388107  76.985910  41.50025  47.003365  ...
# 2019-03-18  41.72940  42.569162  78.724282  41.72940  47.174667  ...
# 2019-03-19  41.92075  42.728509  73.527018  41.92075  47.369412  ...
# 2019-03-20  42.12190  42.897587  80.396901  42.12190  47.569044  ...
#
# ...

# %%
# Now let's just select our subject stock information in the PFE stock.
pfe_data = core_stock_data[core_stock_data['Ticker'] == 'PFE']
print(pfe_data.head())
# Out:
#             Close_core  Volume_core  Open_core  High_core   Low_core  \
# Date
# 2019-03-14   39.079697     32119596  39.848198  39.924099  39.022770
# 2019-03-15   39.639469     74768652  39.117645  39.734344  38.766602
# 2019-03-18   39.667931     18994345  39.629982  39.914612  39.516129
# 2019-03-19   40.132828     26403227  39.819733  40.256168  39.611008
# 2019-03-20   40.009487     23499035  40.037952  40.227703  39.639469
#
#              SMA_core   EMA_core   RSI_core   BBM_core   BBU_core  ...  \
# Date                                                               ...
# 2019-03-14  40.066793  40.146930  32.681000  40.066793  41.614251  ...
# 2019-03-15  40.038899  40.127029  38.351272  40.038899  41.565321  ...
# 2019-03-18  40.034535  40.109025  39.099076  40.034535  41.563984  ...
# 2019-03-19  40.021252  40.109959  44.705898  40.021252  41.535132  ...
# 2019-03-20  40.001139  40.106019  39.575966  40.001139  41.487593  ...
#
# ...

# %% [markdown]
# #### Note above that the starting date is 03-14, this is because of the rolling windows when we calculated our SMA (Single Moving Average).  With our setting of 50 days for the window it was offset by the starting date of 01-01-2019, and we needed a whole window to compute.  So the date you see above in 03-14 starts a new window for us.

# %% [markdown]
# #### Let's begin our EDA analysis with a simple look at Closing price over time.

# %%
# Convert the dates to a numerical format (ordinal) for regression
pfe_data = pfe_data.copy()
pfe_data.loc[:, 'date_ordinal'] = pfe_data.index.map(pd.Timestamp.toordinal)

# Perform linear regression on date ordinals
slope, intercept, r_value, p_value, std_err = linregress(pfe_data['date_ordinal'], pfe_data['Close_core'])

# Calculate the regression line using the slope and intercept
pfe_data.loc[:, 'regression_line'] = slope * pfe_data['date_ordinal'] + intercept

# Plot the closing prices and the regression line
plt.figure(figsize=(10, 6))

# Plot close prices
sns.lineplot(x=pfe_data.index, y=pfe_data['Close_core'], label='Close Price')

# Plot the linear regression line
plt.plot(pfe_data.index, pfe_data['regression_line'], label='Linear Trend', color='red', linestyle='--')

# Set plot title and labels
plt.title('PFE Closing Price with Linear Trend Line')
plt.xlabel('Date')
plt.ylabel('Price')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add a legend
plt.legend()

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Key Takeaways:  PFE experienced fluctuation in pricing during our observation period.  Looking into historical events we can see:
# #### (2019 - 2022) Pfizer's growth during this period largely hinged on the development of the COVID-19 vaccine, as its prices soared throughout this time.
#
# #### (2022 - 2024) Since the end of the pandemic and the end of the need for the vaccine for COVID PFE prices have returned to pre-pandemic era norms, albeit even a bit lower.

# %% [markdown]
# #### Now let's look at Volume over the same period for PFE.

# %%
# Resample the data to monthly frequency ('ME' means month-end)
pfe_monthly = pfe_data.resample('ME').sum()

# Plot using Matplotlib
plt.figure(figsize=(12, 6))  # Larger figure size for better readability

# Plot the monthly volume as bars with better bar width
plt.bar(pfe_monthly.index, pfe_monthly['Volume_core'], color='cyan', width=20)

# Set the title and labels
plt.title('PFE Monthly Volume Over Time', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Volume', fontsize=12)

# Improve the x-axis tick appearance (rotate and format the dates)
plt.xticks(rotation=45, ha='right', fontsize=10)

# Display the plot with tight layout
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Looking at the above monthly Volume for PFE we can see a couple things.  The volume is actually pretty consistent throughout the viewing period, with the trading volume hitting its highest point towards the most recent point in 2024.  This is a change from other core stocks you will see in this project.

# %% [markdown]
# #### Now let's look at the SMA and EMA (Simple Moving Average and Exponential Moving Average, respectively) for PFE, to see what trends exist in this time period.

# %%
plt.figure(figsize=(12, 6))  # Larger figure for readability

# Plot the close price
sns.lineplot(x=pfe_data.index, y=pfe_data['Close_core'], label='Close Price')

# Plot the SMA if it exists
if 'SMA_core' in pfe_data.columns:
    sns.lineplot(x=pfe_data.index, y=pfe_data['SMA_core'], label='SMA 50')

# Plot the EMA if it exists
if 'EMA_core' in pfe_data.columns:
    sns.lineplot(x=pfe_data.index, y=pfe_data['EMA_core'], label='EMA 50')

# Set plot title and labels
plt.title('PFE Closing Price with SMA and EMA', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price', fontsize=12)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right', fontsize=10)

# Add a legend
plt.legend()

# Display the plot with tight layout
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Let's take a look at this one, as it introduces some new concepts.  Only looking at the SMA and EMA lines for a second (the red and the green lines) if both of them are sloping upwards it can indicate a short-term uptrend in the price and and confirm a bullish momentum.  We can clearly see this in several positions on our plot, notably in Mar 2021 - Mar 2022.  Conversely if these lines are together moving down then it can indicate a short-term downtrend or bearish momentum.
#
# #### Now if the Closing Price is above our SMA and EMA lines then it indicates that the stock is trending above the recent average and shows suggested continued strength.  This can also be illustrated in the same periods noted above.
#
# #### Looking at SMA vs EMA, if the SMA is *above* the EMA line this suggests that the the recent pricing is weaker and can indicate a price slow or momentum downshift.  Conversely if the EMA line is above the SMA line it can indicate a positive price shift and momentum upturn, which we can see examples of in Apr 15 - Jun 8 of 2020 and Oct 28 of 2022 - Jan 6 of 2023.

# %% [markdown]
# #### Now let's look at our RSI (Relative Strength Index) for our PFE data.

# %%
# Resample the data to monthly frequency ('ME' means month-end)
pfe_monthly = pfe_data.resample('ME').agg({
    'Close_core': 'last',
    'RSI_core': 'last'
})

plt.figure(figsize=(12, 6)) 

# Plot the RSI line
sns.lineplot(x=pfe_monthly.index, y=pfe_monthly['RSI_core'], label='RSI')

# Plot the Overbought line (70)
plt.plot(pfe_monthly.index, [70] * len(pfe_monthly), label='Overbought (70)', color='red', linestyle='--')

# Plot the Oversold line (30)
plt.plot(pfe_monthly.index, [30] * len(pfe_monthly), label='Oversold (30)', color='green', linestyle='--')

# Set plot title and labels
plt.title('PFE Monthly RSI Over Time', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('RSI', fontsize=12)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right', fontsize=10)

# Add a legend
plt.legend()

# Display the plot with tight layout
plt.tight_layout()
plt.show()

# %% [markdown]
# #### This plot above is very interesting as it can show us potential price shifts.  The red line for Overbought indicates that while the price has been strong it could be due for a reversal or a decrease.  You can see this happen multiple times over this plot with the sudden spike over the red line, then a quick dip back below.  This can take a while to happen, but eventually does.
#
# #### Let's also look at the Oversold line.  Similarly to the Overbought line this line indicates when a positive shift in price is about to happen.  So when the RSI value dips below the green line the signs point toward an increase in pricing.  This can also be viewed in the plot numerous times, especially in Jan 31 - Feb 29 of 2020 and Jan 31 - Feb 28 of 2023.
#
# #### One unusual trend found here with Pfizer is that every year in the viewing window the RSI dips below the Oversold line exactly on Jan 31 and comes back through it on Feb 28/29.  More analysis would need to be done with more historical information but this was an interesting find.

# %% [markdown]
# #### Now let's make use of some of the other features in our dataset and make a Candlestick Chart.

# %%
# Resample the data to monthly frequency ('ME' means month-end)
pfe_monthly_candles = pfe_data.resample('ME').agg({
        'Open_core': 'first',
        'High_core': 'max',
        'Low_core': 'min',
        'Close_core': 'last',
        'Volume_core': 'sum',
        'SMA_core': 'last',
        'EMA_core': 'last'
})

# Preparing the data for mplfinance (it requires OHLC data with a specific format)
pfe_monthly_candles_mpf = pfe_monthly_candles[['Open_core', 'High_core', 'Low_core', 'Close_core', 'Volume_core']]

# Rename the columns to match mplfinance expectations
pfe_monthly_candles_mpf.columns = ['Open', 'High', 'Low', 'Close', 'Volume']

# Plot the candlestick chart with mplfinance
mpf.plot(pfe_monthly_candles_mpf, type='candle', style='yahoo', 
        title='PFE Candlestick Chart with SMA and EMA', 
        ylabel='Price', 
        addplot=[mpf.make_addplot(pfe_monthly_candles['SMA_core'], color='blue', label='SMA 50'),
                mpf.make_addplot(pfe_monthly_candles['EMA_core'], color='orange', label='EMA 50')],
        volume=True, ylabel_lower = 'Volume')

plt.show()

# %% [markdown]
# #### Candlestick charts are great at showing a lot of information.  The size of the candle shows the range of pricing in the given window, in our case a month.  The color (green for positive change, red for negative) will dictate how the final closing price was settled (final closing - beginning opening price for the total window, again a month here).
#
# #### You can then begin to see trends just by noticing the colors, although there are other parts of the candlestick too.  You can notice buyer/seller behavior by looking at successive green or red candlesticks.  If you see multiple long red candlesticks together it could mean that sellers are pushing prices lower.  This can be demonstrated in PFE from Apr 2023 - Feb 2024.  Conversely successive green candlesticks can show buyer behavior pushing positive price changes.  This can be show in several places, especially from Jun - Aug of 2021.

# %% [markdown]
# #### Now let's look at a correlation heatmap to see which indicators are most closely related to price movements for our PFE stock.

# %%
# Calculate the correlation matrix
corr_matrix = pfe_data[['Open_core', 'High_core', 'Low_core', 'Volume_core', 'Close_core', 'EMA_core', 'SMA_core', 'RSI_core', 'BBM_core', 'BBL_core', 'BBU_core', 'MACD_core', 'MACD_Signal_core', 'MACD_Hist_core', 'ADX_14_core', 'CCI_20_core', 'ATR_14_core', 'Stoch_K_core', 'Stoch_D_core', 'Momentum_1_core', 'Momentum_3_core', 'Momentum_7_core', 'Momentum_30_core', 'Momentum_50_core', 'OBV_core']].corr()

# Create a figure and axis
plt.figure(figsize=(12, 10))

# Plot the heatmap
sns.heatmap(corr_matrix, annot=True, cmap='viridis', linewidths=0.5, fmt=".2f")

# Set the title
plt.title('Correlation Matrix of PFE Features', fontsize=16)

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# #### For the above correlation plot we are looking at which features correlate the strongest with our Close price, as that is going to be our strongest driver for this project.  Looking at our colorbar a score of 1 is very strong, and this chart shows that our SMA_core and EMA_core have very strong correlations with our Close Price, while oru Bollinger Band features still correlate relatively well also.  We will still look to try to use the other features as possible when we get to the modeling stage.

# %% [markdown]
# #### Now let's look at a distribution of daily returns for PFE.

# %%
# Calculating the daily returns
pfe_data['daily_return'] = pfe_data['Close_core'].pct_change()

# Drop NaN values for the daily returns
daily_returns = pfe_data['daily_return'].dropna()

# Calculate the KDE for the daily returns
kde = gaussian_kde(daily_returns)
x_vals = np.linspace(daily_returns.min(), daily_returns.max(), 1000)
kde_vals = kde(x_vals)

# Plotting the histogram of daily returns
plt.figure(figsize=(12, 6))

# Plot the histogram of daily returns without the KDE
hist_values, bin_edges, _ = plt.hist(daily_returns, bins=50, color='blue', alpha=0.6, label='Histogram', density=False)

# Scale the KDE to match the histogram's max frequency
scaling_factor = max(hist_values) / max(kde_vals)
kde_vals_scaled = kde_vals * scaling_factor

plt.plot(x_vals, kde_vals_scaled, color = 'red', label = 'KDE', linewidth = 2)

# Set plot title and labels
plt.title('Distribution of PFE Daily Returns with KDE', fontsize=16)
plt.xlabel('Daily Return', fontsize=12)
plt.ylabel('Density', fontsize=12)

# Add a legend
plt.legend()

# Display the plot with tight layout
plt.tight_layout()
plt.show()

# %% [markdown]
# #### There are some key takeaways from our distribution chart.  The first one is that the distribution is mostly centered around 0, with very little spread from the center.  With this near symmetry it suggests that positive and negative are both likely and that there is no strong bias in the direction of the returns.  Also with it being a normal distribution it shows that our PFE stock behaves in a predictable manner, where extreme returns are rare.  The minimal spread (distance away from 0) indicates low volatility as well.

# %% [markdown]
# #### Let's now look at a Rolling Mean and Volatility plot.  We will use this to understand the stability of price movements over time, as it is helpful to identify periods of high uncertainty and/or strong trends in our pricing.

# %%
#### First let's create the rolling mean and rolling std needed for this plot.
#### We will keep the same window size as our SMA and EMA windows for consistency and to also help us as we view the long-term analysis.
pfe_data.loc[:, 'Rolling_Mean'] = pfe_data['Close_core'].rolling(window = 50).mean()
pfe_data.loc[:, 'Rolling_Std'] = pfe_data['Close_core'].rolling(window = 50).std()

# Create a figure and axis with a secondary y-axis for the rolling standard deviation (volatility)
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot the rolling mean on the primary y-axis
ax1.plot(pfe_data.index, pfe_data['Rolling_Mean'], label='Rolling Mean', color='blue')

# Set the labels for the primary y-axis
ax1.set_xlabel('Date')
ax1.set_ylabel('Price', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Create a secondary y-axis for the rolling standard deviation (volatility)
ax2 = ax1.twinx()

# Plot the rolling standard deviation (volatility) on the secondary y-axis
ax2.plot(pfe_data.index, pfe_data['Rolling_Std'], label='Rolling Std (Volatility)', color='red', linestyle='--')

# Set the labels for the secondary y-axis
ax2.set_ylabel('Volatility (Rolling Std)', color='red')
ax2.tick_params(axis='y', labelcolor='red')

# Set plot title and add a legend for both axes
fig.suptitle('PFE Rolling Mean and Volatility', fontsize=16)

# Display the plot with tight layout
fig.tight_layout()
plt.show()

# %% [markdown]
# #### In this plot above we can see again the price increase over the two year pandemic period then coming sharply downward over time in the blue line that is the Rolling Mean.  Our previous plots have shown this as well a bit this is just more reinforcement and a bit more demonstrative of that fact.  The red line in the Rolling Std is a bit more important as it displays Volatility.  Our window size of 50 days plays a part in this too as it will smooth out short-term volatility and provide a longer-term view of that price stability.  As we can see the price for AAPL (barring a couple speedbumps) is relatively normal, with little volatility over the timeframe.

# %% [markdown]
# #### We will now look at a few of the plots whose features correlated most closely with our target Price.  We will take these last few plots and look at some Bollinger Bands and On-Balance Volume for our PFE data.

# %%
# Create the figure and axis
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot the OBV on the primary y-axis
ax1.plot(pfe_data.index, pfe_data['OBV_core'], label='OBV', color='blue')
ax1.set_xlabel('Date')
ax1.set_ylabel('OBV', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Create a secondary y-axis for the Close Price
ax2 = ax1.twinx()
ax2.plot(pfe_data.index, pfe_data['Close_core'], label='Close Price', color='red')
ax2.set_ylabel('Close Price', color='red')
ax2.tick_params(axis='y', labelcolor='red')

# Set the title
plt.title("On-Balance Volume (OBV) and Close Price for PFE", fontsize=16)

# Add legends for both lines
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Display the plot with tight layout
fig.tight_layout()
plt.show()

# %% [markdown]
# #### OBV (On-Balance Volume) can provide valuable insights into the relationship between price movements and trading volume.  We can show the confirmation of the trend when the OBV line is moving in the same direction as the Price line (for the second half of the plot mostly) as it would suggest that the price trend is backed by the volume, indicating the momentum direction.
# #### OBV often acts as a leading indicator and predictor of the Price, as you can see above in large portions of the plot it mirrors our Price movements and is just ahead (predicted) just before the actual time period.  Especially during the year of 2023 they mirror each other really well.

# %% [markdown]
# #### For our last plot in our EDA notebook we will look at all 3 of the Bollinger Bands with a Close price overlay.  The Bollinger Bands were our other high correlator in our correlation matrix above.  Let's see what we can derive from it.

# %%
# Create the figure and axis
plt.figure(figsize=(12, 6))

# Plot the Upper Bollinger Band
plt.plot(pfe_data.index, pfe_data['BBU_core'], label='Upper Bollinger Band', color='green', linewidth=2, alpha=0.4)

# Plot the Middle Bollinger Band (BBM)
plt.plot(pfe_data.index, pfe_data['BBM_core'], label='Middle Bollinger Band', color='orange', linewidth=2, alpha=0.6)

# Plot the Lower Bollinger Band (BBL)
plt.plot(pfe_data.index, pfe_data['BBL_core'], label='Lower Bollinger Band', color='red', linewidth=2, alpha=0.4)

# Plot the Close Price
plt.plot(pfe_data.index, pfe_data['Close_core'], label='Close Price', color='blue', linewidth=3)

# Set the plot title and labels
plt.title("Bollinger Bands with Close Price for PFE", fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price', fontsize=12)

# Add the legend
plt.legend()

# Display the plot with tight layout
plt.tight_layout()
plt.show()

# %% [markdown]
# #### The above Bollinger Bands plot with Closing Price combines a lot of features and information we have seen in this notebook to give a clear picture of the stock data and whether it is relatively high or low.  The Close price will oscillate between the Upper and Lower bands (Green and Red, respectively).  Now when the Close Price touches these bands and moves through it, this can indicate Overbought or Oversold conditions (much like our RSI plot above).
# #### The width of the bands can also show volatility, where a wider band visual indicates increased volatility and conversely shortened or decreased band width can indicated less volatility for that time period.
# #### What to look out for is when the Price does indeed break outside of the bands, as that is when something unique or unusual is happening.  In the above while the Price for PFE touches the outside bands multiple times, PFE's price only exceeds the bands a few times: Nov 27 of 2020 - Dec 11 of 2020 and July 20 - Aug 29 of 2021.

# %% [markdown]
# ## Summary of Findings for PFE
# #### We have taken a good look at our PFE stock covering the given time period.  Here is some of the key takeaways from our plots:
#
# #### -PFE Stock Price has shown to be a consistent performer with minimal volatility, albeit with decreasing stock price in our current viewing window.
# #### -PFE's Closing Price is strongly correlated with the SMA (Single Moving Average) and EMA (Exponential Moving Average) as well as Bollinger Band data.
# #### -PFE's price behaves in a somewhat predictable manner, due to its On-Balance Volume data.  PFE shouldn't rely on this alone for predictions however.
